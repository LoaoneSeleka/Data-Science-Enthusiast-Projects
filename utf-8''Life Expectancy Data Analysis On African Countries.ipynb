# %% [markdown]
# # Life Expectancy Data Analysis

# %%
#Import Python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Set default visualization style
# %matplotlib inline
sns.set()

# %%
#Import csv file and return first 5 records
df = pd.read_csv('life expectancy.csv',sep = ';')
df.head()
# Out:
#        Country  Year      Status  Life_expectancy  Adult_mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant_deaths  Alcohol  Percentage_expenditure  Hepatitis_B  Measles  \
# 0             62     0.01               71.279624         65.0     1154
# 1             64     0.01               73.523582         62.0      492
# 2             66     0.01               73.219243         64.0      430
# 3             69     0.01               78.184215         67.0     2787
# 4             71     0.01                7.097109         68.0     3013
#
#      ...      Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  \
# ...

# %%
#Shape of the dataset. 2938 rows and 22 columns
df.shape
# Out:
# (2938, 22)

# %%
#Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life_expectancy                    2928 non-null float64
# Adult_mortality                    2928 non-null float64
# Infant_deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# Percentage_expenditure             2938 non-null float64
# Hepatitis_B                        2385 non-null float64
# Measles                            2938 non-null int64
# BMI                                2904 non-null float64
# Under_five_deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total_expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
# ...

# %%
#Summary Statistics
df.describe()
# Out:
#               Year  Life_expectancy  Adult_mortality  Infant_deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage_expenditure  Hepatitis_B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
#Retrieving missing values in the dataframe
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expectancy                     10
# Adult_mortality                     10
# Infant_deaths                        0
# Alcohol                            194
# Percentage_expenditure               0
# Hepatitis_B                        553
# Measles                              0
# BMI                                 34
# Under_five_deaths                    0
# Polio                               19
# Total_expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# Thinness _1-19_years                34
#  thinness 5-9 years                 34
# Income_composition_of_resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis on African Countries

# %% [markdown]
# We will be exploring data from African countries to learn more about their life expectancy

# %%
#Create a dataframe with all african countries
df_africa = df.loc[df.Country.isin(['South Africa','Algeria','Angola','Botswana','Burkina Faso','Burundi','Cote te dIvoire','Cameroon',
                                   'Central African Republic','Chad','Congo','Egypt','Equatorial Guinea','Ethiopia','Gabon','Gambia',
                                   'Ghana','Guinea','Kenya','Lesotho','Liberia','Libya','Madagascar','Malawi','Mali','Morocco','Mozambique',
                                   'Namibia','Niger','Nigeria','Rwanda','Senegal','Seychelles','Sierra Leone','Somalia','South Africa',
                                    'South Sudan','Sudan','Swaziland','Togo','Turkey','Uganda','Zambia','Zimbabwe'])]
df_africa.head()
# Out:
#     Country  Year      Status  Life_expectancy  Adult_mortality  \
# 32  Algeria  2015  Developing             75.6             19.0
# 33  Algeria  2014  Developing             75.4             11.0
# 34  Algeria  2013  Developing             75.3            112.0
# 35  Algeria  2012  Developing             75.1            113.0
# 36  Algeria  2011  Developing             74.9            116.0
#
#     Infant_deaths  Alcohol  Percentage_expenditure  Hepatitis_B  Measles  \
# 32             21      NaN                0.000000         95.0       63
# 33             21     0.01               54.237318         95.0        0
# 34             21     0.53              544.450743         95.0       25
# 35             21     0.66              555.926083         95.0       18
# 36             21     0.56              509.002041         95.0      112
#
#       ...      Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# ...

# %%
#The shape of the arican dataframe. 608 rows and 22 columns
df_africa.shape
# Out:
# (688, 22)

# %%
#Column names in the african dataframe
df_africa.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_mortality',
#        'Infant_deaths', 'Alcohol', 'Percentage_expenditure', 'Hepatitis_B',
#        'Measles', 'BMI', 'Under_five_deaths', 'Polio', 'Total_expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'Thinness _1-19_years',
#        ' thinness 5-9 years', 'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %%
#Information about the african dataframe
df_africa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 688 entries, 32 to 2937
# Data columns (total 22 columns):
# Country                            688 non-null object
# Year                               688 non-null int64
# Status                             688 non-null object
# Life_expectancy                    688 non-null float64
# Adult_mortality                    688 non-null float64
# Infant_deaths                      688 non-null int64
# Alcohol                            630 non-null float64
# Percentage_expenditure             688 non-null float64
# Hepatitis_B                        496 non-null float64
# Measles                            688 non-null int64
# BMI                                656 non-null float64
# Under_five_deaths                  688 non-null int64
# Polio                              677 non-null float64
# Total_expenditure                  618 non-null float64
# Diphtheria                         677 non-null float64
# ...

# %%
#Summary statistics on african dataframe
df_africa.describe()
# Out:
#               Year  Life_expectancy  Adult_mortality  Infant_deaths  \
# count   688.000000       688.000000       688.000000     688.000000
# mean   2007.500000        57.761628       280.188953      47.359012
# std       4.613126         8.139444       161.919919      82.935151
# min    2000.000000        39.000000         2.000000       0.000000
# 25%    2003.750000        52.075000       146.000000      12.000000
# 50%    2007.500000        56.700000       288.000000      29.000000
# 75%    2011.250000        62.525000       381.250000      54.000000
# max    2015.000000        79.000000       723.000000     576.000000
#
#           Alcohol  Percentage_expenditure  Hepatitis_B        Measles  \
# count  630.000000              688.000000   496.000000     688.000000
# mean     2.865159              112.592917    74.548387    3995.530523
# std      2.986201              226.255683    26.409320   15162.715670
# min      0.010000                0.000000     1.000000       0.000000
# ...

# %%
#Summary statistics for status column in african dataframe
df_africa['Status'].describe()
# Out:
# count            688
# unique             1
# top       Developing
# freq             688
# Name: Status, dtype: object

# %%
#Value counts of the country dataframe
df_africa['Country'].value_counts().head()
# Out:
# Namibia      16
# Congo        16
# Turkey       16
# Liberia      16
# Swaziland    16
# Name: Country, dtype: int64

# %%
#Value counts of the
df_africa['Status'].value_counts()
# Out:
# Developing    688
# Name: Status, dtype: int64

# %%
#Unique year values in the dataframe
df_africa['Year'].unique()
# Out:
# array([2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005,
#        2004, 2003, 2002, 2001, 2000])

# %%
#Check for missing values in the dataframe
df_africa.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expectancy                      0
# Adult_mortality                      0
# Infant_deaths                        0
# Alcohol                             58
# Percentage_expenditure               0
# Hepatitis_B                        192
# Measles                              0
# BMI                                 32
# Under_five_deaths                    0
# Polio                               11
# Total_expenditure                   70
# Diphtheria                          11
# HIV/AIDS                             0
# GDP                                 89
# Population                          96
# Thinness _1-19_years                32
#  thinness 5-9 years                 32
# Income_composition_of_resources     32
# Schooling                           32
# dtype: int64

# %% [markdown]
# ### Data Manipulation of the African DataFrame

# %%
#The first 5 records of the african dataframe
df_africa.head()
# Out:
#     Country  Year      Status  Life_expectancy  Adult_mortality  \
# 32  Algeria  2015  Developing             75.6             19.0
# 33  Algeria  2014  Developing             75.4             11.0
# 34  Algeria  2013  Developing             75.3            112.0
# 35  Algeria  2012  Developing             75.1            113.0
# 36  Algeria  2011  Developing             74.9            116.0
#
#     Infant_deaths  Alcohol  Percentage_expenditure  Hepatitis_B  Measles  \
# 32             21      NaN                0.000000         95.0       63
# 33             21     0.01               54.237318         95.0        0
# 34             21     0.53              544.450743         95.0       25
# 35             21     0.66              555.926083         95.0       18
# 36             21     0.56              509.002041         95.0      112
#
#       ...      Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# ...

# %%
#Get the sum, mean, standard deviation life expectancy of each country
df_life_exp = df_africa.groupby('Country')['Life_expectancy'].agg(['sum','mean','std'])
df_life_exp.head()
# Out:
#                  sum      mean       std
# Country
# Algeria       1177.9  73.61875  1.552726
# Angola         784.3  49.01875  2.838830
# Botswana       896.8  56.05000  7.325026
# Burkina Faso   890.3  55.64375  3.058315
# Burundi        888.6  55.53750  2.823207

# %%
#Get the sum, mean, standard deviation gdp of each country
df_gdp = df_africa.groupby('Country')['GDP'].agg(['sum','mean','std'])
df_gdp.head()
# Out:
#                        sum         mean          std
# Country
# Algeria       45565.654277  2847.853392  1944.888446
# Angola        31602.288722  1975.143045  1675.764567
# Botswana      71972.566899  4498.285431  2388.037233
# Burkina Faso   6565.952549   410.372034   231.188038
# Burundi        2205.045141   137.815321    99.026295

# %%
#Get the mean for adult mortality by country and year 
df_adult_mortality = df_africa.groupby(['Country','Year'])['Adult_mortality'].mean()
df_adult_mortality.head()
# Out:
# Country  Year
# Algeria  2000    145.0
#          2001    145.0
#          2002    145.0
#          2003    146.0
#          2004     14.0
# Name: Adult_mortality, dtype: float64

# %%
#Get the sum of HIV/AIDS per country
df_hiv = df_africa.groupby('Country')['HIV/AIDS'].sum()
df_hiv.head()
# Out:
# Country
# Algeria           1.6
# Angola           37.9
# Botswana        264.4
# Burkina Faso     29.4
# Burundi          49.4
# Name: HIV/AIDS, dtype: float64

# %%
#Get the population sum for each country
df_population = df_africa.groupby('Country')['Population'].sum()
df_population.head()
# Out:
# Country
# Algeria         346397239.0
# Angola          162353587.0
# Botswana         17021878.0
# Burkina Faso     98299117.0
# Burundi          62647147.0
# Name: Population, dtype: float64

# %%
#Get records of the year 2015
df_year = df_africa.loc[df_africa['Year'] == 2015]
df_year.head()
# Out:
#           Country  Year      Status  Life_expectancy  Adult_mortality  \
# 32        Algeria  2015  Developing             75.6             19.0
# 48         Angola  2015  Developing             52.4            335.0
# 336      Botswana  2015  Developing             65.7            256.0
# 400  Burkina Faso  2015  Developing             59.9             26.0
# 416       Burundi  2015  Developing             59.6            288.0
#
#      Infant_deaths  Alcohol  Percentage_expenditure  Hepatitis_B  Measles  \
# 32              21      NaN                     0.0         95.0       63
# 48              66      NaN                     0.0         64.0      118
# 336              2      NaN                     0.0         95.0        0
# 400             38      NaN                     0.0         91.0       99
# 416             21      NaN                     0.0         94.0        9
#
#        ...      Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# ...

# %%
#Create a dataframe of southern african countries
df_southernafrica = df_africa.loc[df_africa.Country.isin(['South Africa','Lesotho','Botswana','Zimbabwe'])]

# %%
#Line plot of southern african countries life expectancy
g = sns.relplot(x = 'Year', y = 'Life_expectancy', kind = 'line', data = df_southernafrica, hue = 'Country')
g.fig.set_figwidth(15)
plt.title('Life expectancy of southen african countries')
plt.show()

# %% [markdown]
# ### Visualization Data Analysis

# %%
#Line plot of year vs life expentancy
g = sns.relplot(x = 'Year', y = 'Life_expectancy', kind = 'line', data = df_africa)
g.fig.set_figheight(5)
g.fig.set_figwidth(15)
plt.title('Life expectancy for every year in african countries')
plt.show()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Distribution plot for life expectancy
plt.figure(figsize=(10,5))
sns.distplot(df_africa['Life_expectancy'])
plt.ylabel('Frequency')
plt.title('Distribution of Life expectancy')
# Out:
# Text(0.5, 1.0, 'Distribution of Life expectancy')

# %%
#Correlation for life expectancy
df_africa.corr()['Life_expectancy'].sort_values(ascending = False)
# Out:
# Life_expectancy                    1.000000
# Income_composition_of_resources    0.631366
# BMI                                0.586237
# Schooling                          0.498439
# Diphtheria                         0.392309
# Polio                              0.373829
# Year                               0.351516
# GDP                                0.310975
# Hepatitis_B                        0.286755
# Percentage_expenditure             0.205605
# Population                         0.131526
# Measles                           -0.136369
# Total_expenditure                 -0.139984
# Infant_deaths                     -0.186988
# Under_five_deaths                 -0.208222
# Thinness _1-19_years              -0.216528
#  thinness 5-9 years               -0.218242
# Alcohol                           -0.227621
# Adult_mortality                   -0.475638
# HIV/AIDS                          -0.505404
# Name: Life_expectancy, dtype: float64

# %%
#Scatter plot of Income_composition_of_resources vs Life_expectancy
g = sns.relplot(x = 'Income_composition_of_resources', y = 'Life_expectancy', kind = 'scatter', data = df_africa)
g.fig.set_figheight(5)
g.fig.set_figwidth(15)
plt.title('Income_composition_of_resources vs Life_expectancy')
plt.show()

# %%
#Barplot of infant deaths per country
g = sns.catplot(x = 'Infant_deaths', y = 'Country', kind = 'bar', data = df_africa )
g.fig.set_figheight(10)
g.fig.set_figwidth(20)
plt.title('Infant deaths per Country')
# Out:
# Text(0.5, 1.0, 'Infant deaths per Country')

# %%
#Scatter plot population vs gdp
g = sns.relplot(x = 'Population', y = 'GDP', kind = 'scatter', data = df_africa)
g.fig.set_figheight(5)
g.fig.set_figwidth(10)
plt.title('Population vs GDP')
# Out:
# Text(0.5, 1.0, 'Population vs GDP')

# %%
#Heat map of the correlation for african countries
plt.figure(figsize=(15,10))
sns.heatmap(df_africa.corr(), annot=True)

# %% [markdown]
# ### Feature Engineering

# %%
#Get the african dataframe first five records
df_africa.head()
# Out:
#     Country  Year      Status  Life_expectancy  Adult_mortality  \
# 32  Algeria  2015  Developing             75.6             19.0
# 33  Algeria  2014  Developing             75.4             11.0
# 34  Algeria  2013  Developing             75.3            112.0
# 35  Algeria  2012  Developing             75.1            113.0
# 36  Algeria  2011  Developing             74.9            116.0
#
#     Infant_deaths  Alcohol  Percentage_expenditure  Hepatitis_B  Measles  \
# 32             21      NaN                0.000000         95.0       63
# 33             21     0.01               54.237318         95.0        0
# 34             21     0.53              544.450743         95.0       25
# 35             21     0.66              555.926083         95.0       18
# 36             21     0.56              509.002041         95.0      112
#
#       ...      Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# ...

# %%
#Drop country column as we will not need it when building our model
df_africa = df_africa.drop('Country', axis = 1)

# %%
#Value counts for status column
df_africa['Status'].value_counts()
# Out:
# Developing    688
# Name: Status, dtype: int64

# %%
#One hot encode the status column
df_africa = pd.get_dummies(df_africa, columns=['Status'])
df_africa.head()
# Out:
#     Year  Life_expectancy  Adult_mortality  Infant_deaths  Alcohol  \
# 32  2015             75.6             19.0             21      NaN
# 33  2014             75.4             11.0             21     0.01
# 34  2013             75.3            112.0             21     0.53
# 35  2012             75.1            113.0             21     0.66
# 36  2011             74.9            116.0             21     0.56
#
#     Percentage_expenditure  Hepatitis_B  Measles   BMI  Under_five_deaths  \
# 32                0.000000         95.0       63  59.5                 24
# 33               54.237318         95.0        0  58.4                 24
# 34              544.450743         95.0       25  57.2                 24
# 35              555.926083         95.0       18  56.1                 24
# 36              509.002041         95.0      112  55.0                 24
#
#           ...          Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# ...

# %% [markdown]
# ### Build Model

# %%
#Get the correlation values for life expectancy column
df_africa.corr()['Life_expectancy'].sort_values(ascending = False)
# Out:
# Life_expectancy                    1.000000
# Income_composition_of_resources    0.631366
# BMI                                0.586237
# Schooling                          0.498439
# Diphtheria                         0.392309
# Polio                              0.373829
# Year                               0.351516
# GDP                                0.310975
# Hepatitis_B                        0.286755
# Percentage_expenditure             0.205605
# Population                         0.131526
# Measles                           -0.136369
# Total_expenditure                 -0.139984
# Infant_deaths                     -0.186988
# Under_five_deaths                 -0.208222
# Thinness _1-19_years              -0.216528
#  thinness 5-9 years               -0.218242
# Alcohol                           -0.227621
# Adult_mortality                   -0.475638
# HIV/AIDS                          -0.505404
# Status_Developing                       NaN
# ...

# %%
#Independent variables
X = df_africa[['Income_composition_of_resources','BMI','Schooling','Diphtheria','Polio','Year','GDP','Hepatitis_B'
               ,'Percentage_expenditure','Population','Measles','Total_expenditure','Infant_deaths','Under_five_deaths'
              ,'Thinness _1-19_years','Alcohol','Adult_mortality','HIV/AIDS','Status_Developing']].values
X[0:5]
# Out:
# array([[7.43000000e-01, 5.95000000e+01, 1.44000000e+01, 9.50000000e+01,
#         9.50000000e+01, 2.01500000e+03, 4.13276292e+03, 9.50000000e+01,
#         0.00000000e+00, 3.98715280e+07, 6.30000000e+01,            nan,
#         2.10000000e+01, 2.40000000e+01, 6.00000000e+00,            nan,
#         1.90000000e+01, 1.00000000e-01, 1.00000000e+00],
#        [7.41000000e-01, 5.84000000e+01, 1.44000000e+01, 9.50000000e+01,
#         9.50000000e+01, 2.01400000e+03, 5.47851700e+02, 9.50000000e+01,
#         5.42373183e+01, 3.91133130e+07, 0.00000000e+00, 7.21000000e+00,
#         2.10000000e+01, 2.40000000e+01, 6.00000000e+00, 1.00000000e-02,
#         1.10000000e+01, 1.00000000e-01, 1.00000000e+00],
#        [7.37000000e-01, 5.72000000e+01, 1.44000000e+01, 9.50000000e+01,
#         9.50000000e+01, 2.01300000e+03, 5.47186677e+03, 9.50000000e+01,
#         5.44450743e+02, 3.83385620e+07, 2.50000000e+01, 7.12000000e+00,
# ...

# %%
#Imputing missing values with the mean
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values = np.nan, strategy = 'mean', verbose=0)
imp = imp.fit(X[:,0:19])
X[:,0:19] = imp.transform(X[:,0:19])

# %%
#Dependent variable
y = df_africa['Life_expectancy'].values
y[0:5]
# Out:
# array([75.6, 75.4, 75.3, 75.1, 74.9])

# %%
#Divife dataframe into train and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (550, 19) (550,)
# (138, 19) (138,)

# %%
#Normalizing
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#Get the coef and intercept
print('Linear Regression coefficient (m)', regressor.coef_)
print('Linear Regression intercept (b)', regressor.intercept_)
# Out:
# Linear Regression coefficient (m) [ 1.81316732  1.90690531  0.86547241  1.04374938  0.73808086  0.18692853
#  -0.78126382 -0.25093328  1.03403505  0.53276817  0.01740331 -0.73461705
#   7.25255209 -8.19277573  0.46614644 -0.2358138  -1.53702634 -3.32776662
#   0.        ]
# Linear Regression intercept (b) 57.71072727272728

# %%
#Score training set
print(regressor.score(X_train, y_train))
# Out:
# 0.7718028120156186

# %%
#Score test set
print(regressor.score(X_test, y_test))
# Out:
# 0.7474146756616042

# %% [markdown]
# ### Test model

# %%
#Actual values
y_test[0:20]
# Out:
# array([63.8, 45.3, 75.4, 72.7, 47.8, 72.3, 55.9, 54. , 61.6, 71.5, 59.4,
#        71.4, 65.8, 45.9, 58. , 44.3, 64.2, 45.1, 57.8, 71.6])

# %%
#Predict values
y_pred = regressor.predict(X_test)
y_pred[0:20]
# Out:
# array([59.62938782, 52.89602434, 75.04980511, 66.57110778, 43.66845407,
#        70.6372543 , 57.96440868, 53.83505448, 62.20049152, 73.44645274,
#        55.31119537, 70.0308843 , 64.56830327, 49.85135707, 54.86243969,
#        56.36675348, 61.69609832, 46.18291841, 58.86155994, 70.03864264])

# %% [markdown]
# ### Evaluate Model

# %%
from sklearn.metrics import mean_squared_error, r2_score
#Print variance and RMSE
print('Variance: %s' % r2_score(y_test,y_pred)) #0 is worse, 1 is best
print('RMSE: %s' % mean_squared_error(y_test,y_pred)) # the lower the better
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: {}".format(rmse))
# Out:
# Variance: 0.7474146756616042
# RMSE: 18.22914877585226
# Root Mean Squared Error: 4.269560723991669

# %%
#Scatterplot of truth and predicted values
plt.figure(figsize=(10,5))
plt.scatter(y_test, y_pred, color = 'red')
plt.ylabel('Model Predictions')
plt.xlabel('True values (Ground Truth)')
plt.title('Multiple Linear Regression Predictions')
plt.show()

# %% [markdown]
# ### K-fold Cross Validation

# %%
#Cross validation
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = regressor, X = X_train, y = y_train, cv = 5)
accuracies
# Out:
# array([0.71676712, 0.77861336, 0.78394111, 0.70000988, 0.74973577])

# %%
#mean performance of the cross validation
accuracies.mean()
# Out:
# 0.7458134485112712

# %%
#standard deviation of the performance of cross validation
accuracies.std()
# Out:
# 0.03312580254455856

# %% [markdown]
# ### Ridge and Lasso Regression

# %% [markdown]
# #### Ridge

# %%
from sklearn.linear_model import Lasso, Ridge
regressor_ridge = Ridge(alpha = 100)
regressor_ridge.fit(X_train,y_train)

print('Linear Regression coefficient (m)', regressor_ridge.coef_)
print('Linear Regression intercept (b)', regressor_ridge.intercept_)

y_predict = regressor_ridge.predict(X_test)
y_predict[0:5]
# Out:
# Linear Regression coefficient (m) [ 1.63861453e+00  1.69797360e+00  1.00999822e+00  8.76936833e-01
#   7.18257006e-01  3.78206199e-01 -1.18906667e-04 -2.89814897e-02
#   3.59370930e-01  5.25766551e-01 -1.04894672e-01 -6.29936900e-01
#  -2.60771069e-01 -4.20605386e-01  1.92633664e-01 -4.41675711e-01
#  -1.49638781e+00 -2.66180817e+00  0.00000000e+00]
# Linear Regression intercept (b) 57.71072727272728
# array([59.28712881, 53.64060524, 73.94837143, 69.31811831, 45.75980969])

# %%
from sklearn.metrics import mean_squared_error, r2_score
#Print variance and RMSE
print('Variance: %s' % r2_score(y_test,y_predict)) #0 is worse, 1 is best
print('RMSE: %s' % mean_squared_error(y_test,y_predict)) # the lower the better
rmse = np.sqrt(mean_squared_error(y_test, y_predict))
print("Root Mean Squared Error: {}".format(rmse))
# Out:
# Variance: 0.741946167428242
# RMSE: 18.62381244219568
# Root Mean Squared Error: 4.315531536461723

# %% [markdown]
# #### Lasso

# %%
from sklearn.linear_model import Lasso, Ridge
regressor_lasso = Ridge(alpha = 50)
regressor_lasso.fit(X_train,y_train)

print('Linear Regression coefficient (m)', regressor_lasso.coef_)
print('Linear Regression intercept (b)', regressor_lasso.intercept_)

predict = regressor_lasso.predict(X_test)
predict[0:5]
# Out:
# Linear Regression coefficient (m) [ 1.74395159  1.80081028  1.00958975  0.96588301  0.73332515  0.3002748
#  -0.20252673 -0.13021038  0.50559398  0.55503609 -0.10736275 -0.66299665
#  -0.2318516  -0.5028163   0.26650947 -0.37999623 -1.51427799 -2.94120278
#   0.        ]
# Linear Regression intercept (b) 57.71072727272728
# array([59.42956788, 53.4782926 , 74.50226662, 68.88472191, 44.78138269])

# %%
from sklearn.metrics import mean_squared_error, r2_score
#Print variance and RMSE
print('Variance: %s' % r2_score(y_test,predict)) #0 is worse, 1 is best
print('RMSE: %s' % mean_squared_error(y_test,predict)) # the lower the better
rmse = np.sqrt(mean_squared_error(y_test, predict))
print("Root Mean Squared Error: {}".format(rmse))
# Out:
# Variance: 0.7461513401664499
# RMSE: 18.320324028236012
# Root Mean Squared Error: 4.280224763752018
